# %% [markdown]
# The goal of this notebook is to build a simple NN from scratch, without the NN module.  This should teach someone how, in principle, we could build any arbitrary NN, with any connections, and any loss function.  Couple things to look at - create a single node, connect multiple nodes, create multiple outputs, define a loss function, do back propagation on a single loss, do backpropagation on multiple loss functions on the same network.
#
# Coming out of this, a user should be comfortable peering inside a NN, editing a NN, even if it's created with a base library.

# %%
# Create a neuron from scratch
# Out:
# 2
